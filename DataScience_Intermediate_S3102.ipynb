# %%
! pip install openml

# %%
import openml

data = openml.datasets.get_dataset(151).get_data(dataset_format="dataframe")[0]

data
# Out:
# <ipython-input-7-28e2f5360ea2>:3: FutureWarning: Starting from Version 0.15 `download_data`, `download_qualities`, and `download_features_meta_data` will all be ``False`` instead of ``True`` by default to enable lazy loading. To disable this message until version 0.15 explicitly set `download_data`, `download_qualities`, and `download_features_meta_data` to a bool while calling `get_dataset`.
#   data = openml.datasets.get_dataset(151).get_data(dataset_format="dataframe")[0]
#          date day    period  nswprice  nswdemand  vicprice  vicdemand  \
# 0      0.0000   2  0.000000  0.056443   0.439155  0.003467   0.422915
# 1      0.0000   2  0.021277  0.051699   0.415055  0.003467   0.422915
# 2      0.0000   2  0.042553  0.051489   0.385004  0.003467   0.422915
# 3      0.0000   2  0.063830  0.045485   0.314639  0.003467   0.422915
# 4      0.0000   2  0.085106  0.042482   0.251116  0.003467   0.422915
# ...       ...  ..       ...       ...        ...       ...        ...
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(data["vicprice"], bins=500)
plt.show()

# %%
data["vicprice"].mean()
# Out:
# 0.003467033898305085

# %%
data["nswprice"].mean()
# Out:
# 0.057868310138594635

# %%
import seaborn as sns

sns.scatterplot(data, x="nswprice", y="vicprice")
# Out:
# <Axes: xlabel='nswprice', ylabel='vicprice'>

# %%
data["vicprice"].corr(data["nswprice"])
# Out:
# 0.2860717177157683

# %%
sns.scatterplot(data, x="nswprice", y="vicprice", hue="class")
# Out:
# <Axes: xlabel='nswprice', ylabel='vicprice'>

# %%
sns.scatterplot(data, x="nswdemand", y="vicdemand", hue="class")
# Out:
# <Axes: xlabel='nswdemand', ylabel='vicdemand'>

# %%
data["vicdemand"].corr(data["nswdemand"])
# Out:
# 0.6685009007911055

# %%
sns.boxplot(data[["nswprice", "vicprice", "nswdemand", "vicdemand"]])
# Out:
# <Axes: >

# %%
data["nswprice"].quantile(0.95)
# Out:
# 0.106611

# %%
mask1 = data["nswprice"] >= data["nswprice"].quantile(0.05)
mask2 = data["nswprice"] <= data["nswprice"].quantile(0.95)
mask3 = data["vicprice"] >= data["vicprice"].quantile(0.05)
mask4 = data["vicprice"] <= data["vicprice"].quantile(0.95)
mask5 = data["vicdemand"] >= data["vicdemand"].quantile(0.05)
mask6 = data["vicdemand"] <= data["vicdemand"].quantile(0.95)
mask7 = data["vicdemand"] >= data["vicdemand"].quantile(0.05)
mask8 = data["vicdemand"] <= data["vicdemand"].quantile(0.95)

data1 = data[mask1 & mask2 & mask3 & mask4 & mask5 & mask6 & mask7 & mask8].copy()

data1
# Out:
#          date day    period  nswprice  nswdemand  vicprice  vicdemand  \
# 0      0.0000   2  0.000000  0.056443   0.439155  0.003467   0.422915
# 1      0.0000   2  0.021277  0.051699   0.415055  0.003467   0.422915
# 2      0.0000   2  0.042553  0.051489   0.385004  0.003467   0.422915
# 3      0.0000   2  0.063830  0.045485   0.314639  0.003467   0.422915
# 4      0.0000   2  0.085106  0.042482   0.251116  0.003467   0.422915
# ...       ...  ..       ...       ...        ...       ...        ...
# 45307  0.9158   7  0.914894  0.044224   0.340672  0.003033   0.255049
# 45308  0.9158   7  0.936170  0.044884   0.355549  0.003072   0.241326
# 45309  0.9158   7  0.957447  0.043593   0.340970  0.002983   0.247799
# 45310  0.9158   7  0.978723  0.066651   0.329366  0.004630   0.345417
# 45311  0.9158   7  1.000000  0.050679   0.288753  0.003542   0.355256
#
#        transfer class
# 0      0.414912    UP
# 1      0.414912    UP
# 2      0.414912    UP
# 3      0.414912    UP
# ...

# %%
sns.boxplot(data1[["nswprice", "vicprice", "nswdemand", "vicdemand"]])
# Out:
# <Axes: >

# %%
data1
# Out:
#          date day    period  nswprice  nswdemand  vicprice  vicdemand  \
# 0      0.0000   2  0.000000  0.056443   0.439155  0.003467   0.422915
# 1      0.0000   2  0.021277  0.051699   0.415055  0.003467   0.422915
# 2      0.0000   2  0.042553  0.051489   0.385004  0.003467   0.422915
# 3      0.0000   2  0.063830  0.045485   0.314639  0.003467   0.422915
# 4      0.0000   2  0.085106  0.042482   0.251116  0.003467   0.422915
# ...       ...  ..       ...       ...        ...       ...        ...
# 45307  0.9158   7  0.914894  0.044224   0.340672  0.003033   0.255049
# 45308  0.9158   7  0.936170  0.044884   0.355549  0.003072   0.241326
# 45309  0.9158   7  0.957447  0.043593   0.340970  0.002983   0.247799
# 45310  0.9158   7  0.978723  0.066651   0.329366  0.004630   0.345417
# 45311  0.9158   7  1.000000  0.050679   0.288753  0.003542   0.355256
#
#        transfer class
# 0      0.414912    UP
# 1      0.414912    UP
# 2      0.414912    UP
# 3      0.414912    UP
# ...

# %%
data1["nswprice"].mean() / data1["vicprice"].mean()
# Out:
# 16.968361334802825

# %%
data1["x1"] = data1["nswprice"]
data1["x2"] = data1["vicprice"] * (data1["nswprice"].mean() / data1["vicprice"].mean())

data1
# Out:
#          date day    period  nswprice  nswdemand  vicprice  vicdemand  \
# 0      0.0000   2  0.000000  0.056443   0.439155  0.003467   0.422915
# 1      0.0000   2  0.021277  0.051699   0.415055  0.003467   0.422915
# 2      0.0000   2  0.042553  0.051489   0.385004  0.003467   0.422915
# 3      0.0000   2  0.063830  0.045485   0.314639  0.003467   0.422915
# 4      0.0000   2  0.085106  0.042482   0.251116  0.003467   0.422915
# ...       ...  ..       ...       ...        ...       ...        ...
# 45307  0.9158   7  0.914894  0.044224   0.340672  0.003033   0.255049
# 45308  0.9158   7  0.936170  0.044884   0.355549  0.003072   0.241326
# 45309  0.9158   7  0.957447  0.043593   0.340970  0.002983   0.247799
# 45310  0.9158   7  0.978723  0.066651   0.329366  0.004630   0.345417
# 45311  0.9158   7  1.000000  0.050679   0.288753  0.003542   0.355256
#
#        transfer class        x1        x2
# 0      0.414912    UP  0.056443  0.058829
# ...

# %%
data1[["x1", "x2"]].describe()
# Out:
#                  x1            x2
# count  35672.000000  35672.000000
# mean       0.054182      0.054182
# std        0.019620      0.014318
# min        0.026810      0.025877
# 25%        0.039412      0.043880
# 50%        0.049628      0.058829
# 75%        0.069661      0.058829
# max        0.106611      0.099435

# %%
sns.boxplot(data1[["x1", "x2"]])
# Out:
# <Axes: >

# %%
1 - len(data1)/len(data)
# Out:
# 0.21274717514124297

# %%
data1["x1"].corr(data1["x2"])
# Out:
# 0.720152208378001

# %%
sns.scatterplot(data1, x="x1", y="x2", hue="class")
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
data1["x3"] = data1["nswdemand"]
data1["x4"] = data1["vicdemand"]

sns.boxplot(data1[["x3", "x4"]])
# Out:
# <Axes: >

# %%
data1["x3"].corr(data1["x4"])
# Out:
# 0.517760781669077

# %%
sns.scatterplot(data1, x="x3", y="x4", hue="class")
# Out:
# <Axes: xlabel='x3', ylabel='x4'>
